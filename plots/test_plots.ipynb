# %%
import matplotlib.pyplot as plt

# %%
convert = [421048, 5012,224157,68]  
tside = [415864, 10955,0,548819]
swap = [427398, 2827452, 0, 65240]

labels = ['init', 'flow', 'convert', 'find cut']

fig, axs = plt.subplots(2,2)
axs[0][0].set_title("Convert - 735'680ms")
axs[0][0].pie(convert)

axs[0][1].set_title("T Side - 1'061'569ms")
axs[0][1].pie(tside)

axs[1][0].set_title("Swap - 3'332'808ms")
axs[1][0].pie(swap)

axs[1][1].pie(convert, labels=labels)
handles, _ = axs[1][1].get_legend_handles_labels()
axs[1][1].clear()
axs[1][1].set_axis_off()
axs[1][1].set_title("DinicsOPT - 2'631ms")
axs[1][1].legend(handles, labels)

plt.savefig('pie.pdf')
plt.show()

# %%
ns = [2**i for i in range(10,15)]

times = [3.67905,4.95373,5.74737,6.28229,6.54479,7.88729,7.71893]
times2 =[3.82063,4.74459,4.80972,5.2821,6.30454,9.99025]
times3 =[5.21374,6.60239,7.10145,8.65013,10.8571]

plt.plot(ns,times3)
plt.semilogx()
plt.xticks(ns, list(map(str,ns)))
plt.show()

# %% [markdown]
# # Scaling GH tree on GIRGs Log
# LOG: uni=72 bi=14
# LOG: uni=63 bi=14
# LOG: uni=87 bi=17
# LOG: uni=73 bi=13
# LOG: uni=72 bi=15
# 1024	5.03518
# LOG: uni=235 bi=40
# LOG: uni=256 bi=36
# LOG: uni=286 bi=46
# LOG: uni=240 bi=36
# LOG: uni=233 bi=37
# 2048	6.43349
# LOG: uni=782 bi=110
# LOG: uni=1665 bi=277
# LOG: uni=915 bi=113
# LOG: uni=790 bi=110
# LOG: uni=817 bi=121
# 4096	7.03023
# LOG: uni=7091 bi=987
# LOG: uni=3175 bi=355
# LOG: uni=3788 bi=414
# LOG: uni=3166 bi=369
# LOG: uni=3785 bi=374
# 8192	8.79562

# %% [markdown]
# # time in flow subroutine during GH tree construction is >97%
# measured intel icc + vtune profiler
# on soc-slashdot
# using bidirectional dinics

# %% [markdown]
# # run pairs of GH tree with soc-slashdot (results checked)

# %% [raw]
# n       70068
# avg deg 10.2371
# avgSdeg 10.2342
# avgTdeg 1491.63
# normal pairs	... done in 254367 ms
# bidir pairs	... done in 9822 ms (is <7s with turbo boost)
# bk pairs	... done in 574800 ms

# %% [markdown]
# # cool optimization ideas (to measure later)

# %% [raw]
# - in reverse BFS, avoid loading adj[v][e.rev] -> -e.flow != e.cap
# - dfs ignore nodes in maxLayerS that are not in maxLayerT
# - timestamps to avoid linear time per round

# %% [markdown]
# # search space of random node pairs of as-skitter.txt

# %% [raw]
# n / m   1696415	/ 11095298
# avg deg 13.0809
# ========================
# deg S/T 38	/ 13
# flow    13	13
# NORMAL ROUNDS: 3
# 1	maxLayerS  5
# 	Nodes      1576219	 (33%)
# 	Edges      21964997	 (9%)
# 2	maxLayerS  6
# 	Nodes      1654370	 (14%)
# 	Edges      22120120	 (2%)
# 3	maxLayerS  21
# 	Nodes      1694615	 (0%)
# 	Edges      22188405	 (0%)
# BIDIR ROUNDS:  3
# 1	maxLayerS/T 2	/ 3
# 	Nodes      34903	 (94%)
# 	Edges      1526849	 (95%)
# 2	maxLayerS/T 3	/ 3
# 	Nodes      53140	 (97%)
# 	Edges      4238664	 (98%)
# 3	maxLayerS/T 0	/ 0
# 	Nodes      2	 (100%)
# 	Edges      51	 (100%)
#
# deg S/T 19	/ 3
# flow    3	3
# NORMAL ROUNDS: 3
# 1	maxLayerS  3
# 	Nodes      180264	 (99%)
# 	Edges      9082239	 (95%)
# 2	maxLayerS  5
# 	Nodes      1572798	 (34%)
# 	Edges      21949626	 (10%)
# 3	maxLayerS  20
# 	Nodes      1694615	 (0%)
# 	Edges      22188415	 (0%)
# BIDIR ROUNDS:  3
# 1	maxLayerS/T 1	/ 2
# 	Nodes      26004	 (99%)
# 	Edges      695151	 (95%)
# 2	maxLayerS/T 1	/ 4
# 	Nodes      22134	 (99%)
# 	Edges      619823	 (96%)
# 3	maxLayerS/T 0	/ 0
# 	Nodes      2	 (100%)
# 	Edges      22	 (100%)
#
# deg S/T 3	/ 2
# flow    2	2
# NORMAL ROUNDS: 3
# 1	maxLayerS  4
# 	Nodes      693255	 (89%)
# 	Edges      16953202	 (69%)
# 2	maxLayerS  6
# 	Nodes      1472540	 (50%)
# 	Edges      21699569	 (19%)
# 3	maxLayerS  22
# 	Nodes      1694615	 (0%)
# 	Edges      22188416	 (0%)
# BIDIR ROUNDS:  3
# 1	maxLayerS/T 2	/ 2
# 	Nodes      7261	 (99%)
# 	Edges      173864	 (95%)
# 2	maxLayerS/T 3	/ 3
# 	Nodes      12675	 (99%)
# 	Edges      724672	 (97%)
# 3	maxLayerS/T 0	/ 0
# 	Nodes      2	 (100%)
# 	Edges      5	 (100%)
#
# deg S/T 7	/ 95
# flow    7	7
# NORMAL ROUNDS: 4
# 1	maxLayerS  4
# 	Nodes      700929	 (95%)
# 	Edges      16926110	 (79%)
# 2	maxLayerS  5
# 	Nodes      1382782	 (59%)
# 	Edges      21465934	 (28%)
# 3	maxLayerS  6
# 	Nodes      1588278	 (31%)
# 	Edges      21998096	 (8%)
# 4	maxLayerS  0
# 	Nodes      1	 (100%)
# 	Edges      7	 (100%)
# BIDIR ROUNDS:  4
# 1	maxLayerS/T 2	/ 2
# 	Nodes      14364	 (99%)
# 	Edges      641117	 (96%)
# 2	maxLayerS/T 2	/ 3
# 	Nodes      29708	 (99%)
# 	Edges      1228718	 (92%)
# 3	maxLayerS/T 3	/ 3
# 	Nodes      31941	 (98%)
# 	Edges      1538845	 (94%)
# 4	maxLayerS/T 0	/ 1
# 	Nodes      90	 (98%)
# 	Edges      8829	 (98%)
#
# deg S/T 9	/ 30
# flow    9	9
# NORMAL ROUNDS: 4
# 1	maxLayerS  4
# 	Nodes      786631	 (94%)
# 	Edges      17703805	 (71%)
# 2	maxLayerS  5
# 	Nodes      1483707	 (48%)
# 	Edges      21767414	 (19%)
# 3	maxLayerS  6
# 	Nodes      1662448	 (13%)
# 	Edges      22135324	 (2%)
# 4	maxLayerS  0
# 	Nodes      1	 (100%)
# 	Edges      9	 (100%)
# BIDIR ROUNDS:  4
# 1	maxLayerS/T 2	/ 2
# 	Nodes      1943	 (97%)
# 	Edges      212703	 (98%)
# 2	maxLayerS/T 2	/ 3
# 	Nodes      3105	 (96%)
# 	Edges      357668	 (98%)
# 3	maxLayerS/T 2	/ 4
# 	Nodes      5517	 (96%)
# 	Edges      796391	 (98%)
# 4	maxLayerS/T 0	/ 1
# 	Nodes      23	 (95%)
# 	Edges      85	 (64%)
#
# deg S/T 3	/ 8
# flow    2	2
# NORMAL ROUNDS: 2
# 1	maxLayerS  5
# 	Nodes      1286501	 (68%)
# 	Edges      21114148	 (34%)
# 2	maxLayerS  1
# 	Nodes      2	 (50%)
# 	Edges      4	 (25%)
# BIDIR ROUNDS:  2
# 1	maxLayerS/T 2	/ 3
# 	Nodes      3992	 (91%)
# 	Edges      852046	 (99%)
# 2	maxLayerS/T 1	/ 1
# 	Nodes      9	 (77%)
# 	Edges      799	 (98%)
#
# deg S/T 3	/ 10
# flow    3	3
# NORMAL ROUNDS: 2
# 1	maxLayerS  4
# 	Nodes      897694	 (88%)
# 	Edges      18800483	 (64%)
# 2	maxLayerS  0
# 	Nodes      1	 (100%)
# 	Edges      3	 (100%)
# BIDIR ROUNDS:  2
# 1	maxLayerS/T 2	/ 2
# 	Nodes      8047	 (99%)
# 	Edges      397893	 (95%)
# 2	maxLayerS/T 0	/ 1
# 	Nodes      9	 (88%)
# 	Edges      11347	 (99%)
#
# deg S/T 1	/ 14
# flow    1	1
# NORMAL ROUNDS: 2
# 1	maxLayerS  6
# 	Nodes      1058719	 (85%)
# 	Edges      19819950	 (59%)
# 2	maxLayerS  0
# 	Nodes      1	 (100%)
# 	Edges      1	 (100%)
# BIDIR ROUNDS:  2
# 1	maxLayerS/T 4	/ 2
# 	Nodes      4893	 (97%)
# 	Edges      633648	 (98%)
# 2	maxLayerS/T 0	/ 1
# 	Nodes      15	 (93%)
# 	Edges      4360	 (99%)
#
# deg S/T 1	/ 3
# flow    1	1
# NORMAL ROUNDS: 2
# 1	maxLayerS  6
# 	Nodes      1526226	 (42%)
# 	Edges      21844292	 (15%)
# 2	maxLayerS  0
# 	Nodes      1	 (100%)
# 	Edges      1	 (100%)
# BIDIR ROUNDS:  2
# 1	maxLayerS/T 3	/ 3
# 	Nodes      39820	 (99%)
# 	Edges      2173439	 (96%)
# 2	maxLayerS/T 0	/ 1
# 	Nodes      4	 (75%)
# 	Edges      42	 (92%)
#
# deg S/T 4	/ 5
# flow    4	4
# NORMAL ROUNDS: 4
# 1	maxLayerS  4
# 	Nodes      719159	 (86%)
# 	Edges      17134986	 (63%)
# 2	maxLayerS  5
# 	Nodes      1183496	 (70%)
# 	Edges      20662313	 (41%)
# 3	maxLayerS  7
# 	Nodes      1632682	 (20%)
# 	Edges      22077615	 (4%)
# 4	maxLayerS  0
# 	Nodes      1	 (100%)
# 	Edges      4	 (100%)
# BIDIR ROUNDS:  4
# 1	maxLayerS/T 2	/ 2
# 	Nodes      29926	 (99%)
# 	Edges      1150358	 (97%)
# 2	maxLayerS/T 3	/ 2
# 	Nodes      67234	 (99%)
# 	Edges      3791113	 (92%)
# 3	maxLayerS/T 4	/ 3
# 	Nodes      81252	 (99%)
# 	Edges      4520496	 (90%)
# 4	maxLayerS/T 0	/ 3
# 	Nodes      9	 (66%)
# 	Edges      731	 (98%)
#
# deg S/T 66	/ 8
# flow    8	8
# NORMAL ROUNDS: 6
# 1	maxLayerS  3
# 	Nodes      276889	 (98%)
# 	Edges      10548699	 (93%)
# 2	maxLayerS  4
# 	Nodes      1150366	 (80%)
# 	Edges      20430039	 (53%)
# 3	maxLayerS  5
# 	Nodes      1576994	 (33%)
# 	Edges      21966038	 (10%)
# 4	maxLayerS  6
# 	Nodes      1673798	 (8%)
# 	Edges      22155235	 (1%)
# 5	maxLayerS  8
# 	Nodes      1694078	 (0%)
# 	Edges      22187504	 (0%)
# 6	maxLayerS  21
# 	Nodes      1694615	 (0%)
# 	Edges      22188410	 (0%)
# BIDIR ROUNDS:  6
# 1	maxLayerS/T 1	/ 2
# 	Nodes      8567	 (99%)
# 	Edges      445118	 (98%)
# 2	maxLayerS/T 2	/ 2
# 	Nodes      3877	 (98%)
# 	Edges      597280	 (98%)
# 3	maxLayerS/T 2	/ 3
# 	Nodes      16658	 (98%)
# 	Edges      1631502	 (98%)
# 4	maxLayerS/T 2	/ 4
# 	Nodes      12425	 (98%)
# 	Edges      623816	 (97%)
# 5	maxLayerS/T 2	/ 6
# 	Nodes      55035	 (99%)
# 	Edges      4290461	 (98%)
# 6	maxLayerS/T 0	/ 0
# 	Nodes      2	 (100%)
# 	Edges      74	 (100%)
#
# deg S/T 18	/ 2
# flow    2	2
# NORMAL ROUNDS: 3
# 1	maxLayerS  6
# 	Nodes      1578937	 (31%)
# 	Edges      21975080	 (9%)
# 2	maxLayerS  7
# 	Nodes      1678713	 (5%)
# 	Edges      22163062	 (0%)
# 3	maxLayerS  22
# 	Nodes      1694615	 (0%)
# 	Edges      22188416	 (0%)
# BIDIR ROUNDS:  3
# 1	maxLayerS/T 3	/ 3
# 	Nodes      31804	 (99%)
# 	Edges      944638	 (94%)
# 2	maxLayerS/T 3	/ 4
# 	Nodes      33746	 (99%)
# 	Edges      1142850	 (95%)
# 3	maxLayerS/T 0	/ 0
# 	Nodes      2	 (100%)
# 	Edges      20	 (100%)
#
# deg S/T 8	/ 34
# flow    7	7
# NORMAL ROUNDS: 5
# 1	maxLayerS  5
# 	Nodes      1566338	 (33%)
# 	Edges      21946042	 (10%)
# 2	maxLayerS  6
# 	Nodes      1588019	 (29%)
# 	Edges      21992397	 (8%)
# 3	maxLayerS  7
# 	Nodes      1664470	 (11%)
# 	Edges      22137423	 (1%)
# 4	maxLayerS  8
# 	Nodes      1671685	 (8%)
# 	Edges      22151226	 (1%)
# 5	maxLayerS  1
# 	Nodes      2	 (50%)
# 	Edges      9	 (11%)
# BIDIR ROUNDS:  5
# 1	maxLayerS/T 2	/ 3
# 	Nodes      15869	 (99%)
# 	Edges      1641089	 (96%)
# 2	maxLayerS/T 3	/ 3
# 	Nodes      13116	 (98%)
# 	Edges      756297	 (97%)
# 3	maxLayerS/T 3	/ 4
# 	Nodes      10609	 (96%)
# 	Edges      1130032	 (95%)
# 4	maxLayerS/T 4	/ 4
# 	Nodes      9740	 (97%)
# 	Edges      1101499	 (95%)
# 5	maxLayerS/T 1	/ 1
# 	Nodes      30	 (93%)
# 	Edges      206	 (79%)
#
# deg S/T 1	/ 21
# flow    1	1
# NORMAL ROUNDS: 2
# 1	maxLayerS  5
# 	Nodes      34665	 (98%)
# 	Edges      2401388	 (98%)
# 2	maxLayerS  0
# 	Nodes      1	 (100%)
# 	Edges      1	 (100%)
# BIDIR ROUNDS:  2
# 1	maxLayerS/T 3	/ 2
# 	Nodes      14730	 (99%)
# 	Edges      1124068	 (95%)
# 2	maxLayerS/T 0	/ 1
# 	Nodes      22	 (95%)
# 	Edges      53430	 (99%)
#
# deg S/T 3	/ 5
# flow    3	3
# NORMAL ROUNDS: 3
# 1	maxLayerS  6
# 	Nodes      1577662	 (34%)
# 	Edges      21969574	 (10%)
# 2	maxLayerS  7
# 	Nodes      1678403	 (6%)
# 	Edges      22162444	 (0%)
# 3	maxLayerS  0
# 	Nodes      1	 (100%)
# 	Edges      3	 (100%)
# BIDIR ROUNDS:  3
# 1	maxLayerS/T 3	/ 3
# 	Nodes      16560	 (99%)
# 	Edges      871989	 (97%)
# 2	maxLayerS/T 3	/ 4
# 	Nodes      30959	 (99%)
# 	Edges      1522140	 (97%)
# 3	maxLayerS/T 0	/ 1
# 	Nodes      4	 (75%)
# 	Edges      17	 (70%)
#
# deg S/T 1	/ 2
# flow    1	1
# NORMAL ROUNDS: 2
# 1	maxLayerS  6
# 	Nodes      1432084	 (53%)
# 	Edges      21597753	 (22%)
# 2	maxLayerS  0
# 	Nodes      1	 (100%)
# 	Edges      1	 (100%)
# BIDIR ROUNDS:  2
# 1	maxLayerS/T 3	/ 3
# 	Nodes      2463	 (97%)
# 	Edges      512245	 (99%)
# 2	maxLayerS/T 0	/ 4
# 	Nodes      8	 (50%)
# 	Edges      100	 (90%)
#
# deg S/T 3	/ 34
# flow    1	1
# NORMAL ROUNDS: 2
# 1	maxLayerS  6
# 	Nodes      1306046	 (64%)
# 	Edges      21199827	 (31%)
# 2	maxLayerS  1
# 	Nodes      3	 (66%)
# 	Edges      5	 (40%)
# BIDIR ROUNDS:  2
# 1	maxLayerS/T 4	/ 2
# 	Nodes      25811	 (99%)
# 	Edges      1592660	 (97%)
# 2	maxLayerS/T 1	/ 1
# 	Nodes      37	 (94%)
# 	Edges      499	 (92%)
#
# deg S/T 13	/ 13
# flow    13	13
# NORMAL ROUNDS: 6
# 1	maxLayerS  4
# 	Nodes      1004552	 (82%)
# 	Edges      19259617	 (56%)
# 2	maxLayerS  5
# 	Nodes      1157352	 (75%)
# 	Edges      20394261	 (45%)
# 3	maxLayerS  6
# 	Nodes      1554863	 (36%)
# 	Edges      21924189	 (12%)
# 4	maxLayerS  7
# 	Nodes      1477293	 (47%)
# 	Edges      21734047	 (18%)
# 5	maxLayerS  8
# 	Nodes      1658111	 (13%)
# 	Edges      22126880	 (2%)
# 6	maxLayerS  0
# 	Nodes      1	 (100%)
# 	Edges      13	 (100%)
# BIDIR ROUNDS:  6
# 1	maxLayerS/T 2	/ 2
# 	Nodes      1437	 (98%)
# 	Edges      364843	 (99%)
# 2	maxLayerS/T 3	/ 2
# 	Nodes      16953	 (99%)
# 	Edges      841007	 (96%)
# 3	maxLayerS/T 3	/ 3
# 	Nodes      22012	 (98%)
# 	Edges      1523024	 (97%)
# 4	maxLayerS/T 4	/ 3
# 	Nodes      2555	 (96%)
# 	Edges      171946	 (97%)
# 5	maxLayerS/T 4	/ 4
# 	Nodes      19175	 (98%)
# 	Edges      1837520	 (98%)
# 6	maxLayerS/T 0	/ 0
# 	Nodes      2	 (100%)
# 	Edges      26	 (100%)
#
# deg S/T 5	/ 3
# flow    3	3
# NORMAL ROUNDS: 3
# 1	maxLayerS  5
# 	Nodes      1420397	 (54%)
# 	Edges      21570326	 (24%)
# 2	maxLayerS  6
# 	Nodes      1618060	 (25%)
# 	Edges      22059510	 (5%)
# 3	maxLayerS  21
# 	Nodes      1694615	 (0%)
# 	Edges      22188415	 (0%)
# BIDIR ROUNDS:  3
# 1	maxLayerS/T 2	/ 3
# 	Nodes      15517	 (99%)
# 	Edges      814997	 (97%)
# 2	maxLayerS/T 3	/ 3
# 	Nodes      4544	 (96%)
# 	Edges      1019122	 (99%)
# 3	maxLayerS/T 0	/ 0
# 	Nodes      2	 (100%)
# 	Edges      8	 (100%)
#
# deg S/T 5	/ 7
# flow    5	5
# NORMAL ROUNDS: 4
# 1	maxLayerS  4
# 	Nodes      713529	 (96%)
# 	Edges      16984763	 (78%)
# 2	maxLayerS  5
# 	Nodes      1423559	 (54%)
# 	Edges      21575787	 (24%)
# 3	maxLayerS  6
# 	Nodes      815074	 (94%)
# 	Edges      17919763	 (71%)
# 4	maxLayerS  0
# 	Nodes      1	 (100%)
# 	Edges      5	 (100%)
# BIDIR ROUNDS:  4
# 1	maxLayerS/T 2	/ 2
# 	Nodes      6723	 (99%)
# 	Edges      1056885	 (98%)
# 2	maxLayerS/T 3	/ 2
# 	Nodes      23472	 (95%)
# 	Edges      3668302	 (98%)
# 3	maxLayerS/T 4	/ 2
# 	Nodes      2437	 (97%)
# 	Edges      781944	 (99%)
# 4	maxLayerS/T 0	/ 1
# 	Nodes      4	 (75%)
# 	Edges      65	 (89%)
